# %%
#const successCallback = (position) => {
#   console.log(position);
# };

# const errorCallback = (error) => {
#   console.log(error);
# };

# navigator.geolocation.getCurrentPosition(successCallback, errorCallback);

# %%
import folium

# %%
coordinates = [
[27.705194, 85.391806],
[27.649790, 85.403445],
[27.676529, 85.516931],
]
icon=folium.Icon(icon='bin', icon_size=(20,20))

map = folium.Map(
    location=[27.705194, 85.391806],
    tiles="OpenStreetMap",
    zoom_start=15,
    width="100%",
    height="100%",
    
)
for coordinate in coordinates:
    folium.Marker(coordinate,icon=icon).add_to(map)
# folium.Marker(coordinate, popup="lmao", tooltip="click").add_to(map)

# rendering map html
#map = map._repr_html_()

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7ed07ad54f51e5c076373870cb2568c2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7ed07ad54f51e5c076373870cb2568c2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7ed07ad54f51e5c076373870cb2568c2 = L.map(
#                 &quot;map_7ed07ad54f51e5c076373870cb2568c2&quot;,
#                 {
#                     center: [27.705194, 85.391806],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dc9f2fb1d96999c0cc36888aedaa10b2 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7ed07ad54f51e5c076373870cb2568c2);
#
#
#             var marker_3a50e2116e068ca1af03b52a8d68368e = L.marker(
#                 [27.705194, 85.391806],
#                 {}
#             ).addTo(map_7ed07ad54f51e5c076373870cb2568c2);
#
#
#             var icon_075cb69fe98c0fb69f3b44712b8a9918 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;bin&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;iconSize&quot;: [20, 20], &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d2c242e9cf9897f4ed0c7b315704bfec.setIcon(icon_075cb69fe98c0fb69f3b44712b8a9918);
#
#
#             var marker_f052c6e287a7ca2eaa8b23b5148197ed = L.marker(
#                 [27.64979, 85.403445],
#                 {}
#             ).addTo(map_7ed07ad54f51e5c076373870cb2568c2);
#
#
#             var marker_d2c242e9cf9897f4ed0c7b315704bfec = L.marker(
#                 [27.676529, 85.516931],
#                 {}
#             ).addTo(map_7ed07ad54f51e5c076373870cb2568c2);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## open route source

# %%
key='5b3ce3597851110001cf6248f2b95ebb2fcc45cfb91bae62c6b3735c'

# %%
import requests
start=[8.681495,49.41461]
end=[8.687872,49.420318]

# %%
body = {"coordinates":[start,end],[]}

headers = {
    'Accept': 'application/json, application/geo+json, application/gpx+xml, img/png; charset=utf-8',
    'Authorization': '5b3ce3597851110001cf6248f2b95ebb2fcc45cfb91bae62c6b3735c',
    'Content-Type': 'application/json; charset=utf-8'
}
result = requests.post('https://api.openrouteservice.org/v2/directions/driving-car', json=body, headers=headers)

# %%
####https://openrouteservice.org/dev/#/api-docs/v2/directions/{profile}/get
start_p='85.403445,27.649790,'
end_p='85.516931,27.676529'

# %%
url=f"https://api.openrouteservice.org/v2/directions/driving-car?api_key=5b3ce3597851110001cf6248f2b95ebb2fcc45cfb91bae62c6b3735c&start={start_p}&end={end_p}"

# %%
result=requests.get(url)
result.json()
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'bbox': [85.404827, 27.648867, 85.515817, 27.676479],
#    'type': 'Feature',
#    'properties': {'segments': [{'distance': 17826.5,
#       'duration': 1491.8,
#       'steps': [{'distance': 42.4,
#         'duration': 10.2,
#         'type': 11,
#         'instruction': 'Head southeast',
#         'name': '-',
#         'way_points': [0, 3]},
#        {'distance': 16.3,
#         'duration': 5.9,
#         'type': 0,
#         'instruction': 'Turn left',
#         'name': '-',
#         'way_points': [3, 4]},
#        {'distance': 437.5,
#         'duration': 53.4,
#         'type': 1,
#         'instruction': 'Turn right',
#         'name': '-',
#         'way_points': [4, 15]},
#        {'distance': 276.6,
#         'duration': 33.2,
#         'type': 0,
#         'instruction': 'Turn left onto F99',
#         'name': 'F99',
#         'way_points': [15, 19]},
#        {'distance': 273.8,
#         'duration': 32.9,
#         'type': 4,
#         'instruction': 'Turn slight left onto F99',
#         'name': 'F99',
#         'way_points': [19, 29]},
#        {'distance': 1713.9,
#         'duration': 199.2,
#         'type': 3,
#         'instruction': 'Turn sharp right onto F99',
#         'name': 'F99',
#         'way_points': [29, 82]},
#        {'distance': 1008.8,
#         'duration': 69.3,
#         'type': 12,
#         'instruction': 'Keep left',
#         'name': '-',
#         'way_points': [82, 114]},
#        {'distance': 409.6,
#         'duration': 32.9,
#         'type': 1,
#         'instruction': 'Turn right onto Araniko Highway, NH34',
#         'name': 'Araniko Highway, NH34',
#         'way_points': [114, 121]},
#        {'distance': 942.3,
#         'duration': 39.9,
#         'type': 4,
#         'instruction': 'Turn slight left onto Araniko Highway, H03',
#         'name': 'Araniko Highway, H03',
#         'way_points': [121, 142]},
#        {'distance': 805.8,
#         'duration': 66.5,
#         'type': 0,
#         'instruction': 'Turn left',
#         'name': '-',
#         'way_points': [142, 168]},
#        {'distance': 3045.9,
#         'duration': 187.8,
#         'type': 1,
#         'instruction': 'Turn right onto CHYAMASINGH NALA ROAD, F97',
#         'name': 'CHYAMASINGH NALA ROAD, F97',
#         'way_points': [168, 256]},
#        {'distance': 1497.2,
#         'duration': 89.8,
#         'type': 0,
#         'instruction': 'Turn left onto BHAKTAPUR NALA ROAD (GANESHMAN MARG), F97',
#         'name': 'BHAKTAPUR NALA ROAD (GANESHMAN MARG), F97',
#         'way_points': [256, 290]},
#        {'distance': 1380.6,
#         'duration': 86.1,
#         'type': 13,
#         'instruction': 'Keep right onto Bhaktapur-Nala-Banepa road, F97',
#         'name': 'Bhaktapur-Nala-Banepa road, F97',
#         'way_points': [290, 358]},
#        {'distance': 2377.0,
#         'duration': 152.8,
#         'type': 4,
#         'instruction': 'Turn slight left onto Bhaktapur-Nala-Banepa road, F97',
#         'name': 'Bhaktapur-Nala-Banepa road, F97',
#         'way_points': [358, 436]},
#        {'distance': 59.1,
#         'duration': 7.1,
#         'type': 0,
#         'instruction': 'Turn left',
#         'name': '-',
#         'way_points': [436, 439]},
#        {'distance': 869.8,
#         'duration': 104.4,
#         'type': 2,
#         'instruction': 'Turn sharp left',
#         'name': '-',
#         'way_points': [439, 477]},
#        {'distance': 807.9,
#         'duration': 96.9,
#         'type': 1,
#         'instruction': 'Turn right',
#         'name': '-',
#         'way_points': [477, 521]},
#        {'distance': 695.5,
#         'duration': 83.5,
#         'type': 4,
#         'instruction': 'Turn slight left onto 24DR004',
#         'name': '24DR004',
#         'way_points': [521, 552]},
#        {'distance': 274.9,
#         'duration': 33.0,
#         'type': 1,
#         'instruction': 'Turn right',
#         'name': '-',
#         'way_points': [552, 565]},
#        {'distance': 260.3,
#         'duration': 31.2,
#         'type': 13,
#         'instruction': 'Keep right onto 24DR004',
#         'name': '24DR004',
#         'way_points': [565, 575]},
#        {'distance': 631.3,
#         'duration': 75.8,
#         'type': 12,
#         'instruction': 'Keep left onto 24DR004',
#         'name': '24DR004',
#         'way_points': [575, 594]},
#        {'distance': 0.0,
#         'duration': 0.0,
#         'type': 10,
#         'instruction': 'Arrive at 24DR004, on the right',
#         'name': '-',
#         'way_points': [594, 594]}]}],
#     'summary': {'distance': 17826.5, 'duration': 1491.8},
#     'way_points': [0, 594]},
#    'geometry': {'coordinates': [[85.404827, 27.650501],
#      [85.404919, 27.650411],
#      [85.404945, 27.650384],
#      [85.405104, 27.650209],
#      [85.405212, 27.650319],
#      [85.405395, 27.650236],
#      [85.405789, 27.650141],
#      [85.406454, 27.649946],
#      [85.406763, 27.649787],
#      [85.407428, 27.649523],
#      [85.407704, 27.649466],
#      [85.407878, 27.649397],
#      [85.408377, 27.649245],
#      [85.409083, 27.648934],
#      [85.409241, 27.648875],
#      [85.409319, 27.648867],
#      [85.409579, 27.649341],
#      [85.40976, 27.64991],
#      [85.410178, 27.650388],
#      [85.411042, 27.650365],
#      [85.411168, 27.650458],
#      [85.411255, 27.65058],
#      [85.411295, 27.650721],
#      [85.411284, 27.650865],
#      [85.411223, 27.650999],
#      [85.411034, 27.651271],
#      [85.410971, 27.651536],
#      [85.410798, 27.651717],
#      [85.410791, 27.652133],
#      [85.410858, 27.652625],
#      [85.410895, 27.652559],
#      [85.410908, 27.652237],
#      [85.410957, 27.652104],
#      [85.410951, 27.651854],
#      [85.411637, 27.651566],
#      [85.411903, 27.651551],
#      [85.412371, 27.651627],
#      [85.412418, 27.651634],
#      [85.412615, 27.651748],
#      [85.412915, 27.652037],
#      [85.413209, 27.65258],
#      [85.413291, 27.652789],
#      [85.4133, 27.652868],
#      [85.413288, 27.652942],
#      [85.413121, 27.653345],
#      [85.413053, 27.653619],
#      [85.412872, 27.653999],
#      [85.412786, 27.654441],
#      [85.412673, 27.654795],
#      [85.412646, 27.654924],
#      [85.412637, 27.655077],
#      [85.412685, 27.655606],
#      [85.412643, 27.655953],
#      [85.41266, 27.656087],
#      [85.412755, 27.656432],
#      [85.412712, 27.657114],
#      [85.412491, 27.657673],
#      [85.412448, 27.658018],
#      [85.412418, 27.658082],
#      [85.412069, 27.658534],
#      [85.412019, 27.658644],
#      [85.412015, 27.658739],
#      [85.412048, 27.659034],
#      [85.412103, 27.659299],
#      [85.412138, 27.659407],
#      [85.41221, 27.659568],
#      [85.412434, 27.659764],
#      [85.412477, 27.659847],
#      [85.412489, 27.659918],
#      [85.412357, 27.660392],
#      [85.41237, 27.660543],
#      [85.412503, 27.661236],
#      [85.412535, 27.661309],
#      [85.412591, 27.661367],
#      [85.412872, 27.661601],
#      [85.413147, 27.661791],
#      [85.413241, 27.661892],
#      [85.4133, 27.662014],
#      [85.413538, 27.662335],
#      [85.414098, 27.662711],
#      [85.414329, 27.662809],
#      [85.414763, 27.662796],
#      [85.4151, 27.662725],
#      [85.415624, 27.662762],
#      [85.415988, 27.662754],
#      [85.41611, 27.662732],
#      [85.416332, 27.662649],
#      [85.416875, 27.662363],
#      [85.417167, 27.662275],
#      [85.417754, 27.662206],
#      [85.419298, 27.662251],
#      [85.419542, 27.66227],
#      [85.419835, 27.662314],
#      [85.419899, 27.662336],
#      [85.42008, 27.66253],
#      [85.420143, 27.662584],
#      [85.420234, 27.66269],
#      [85.420395, 27.662868],
#      [85.420822, 27.663527],
#      [85.420926, 27.663596],
#      [85.421027, 27.663606],
#      [85.421082, 27.663624],
#      [85.421255, 27.663793],
#      [85.42135, 27.663952],
#      [85.421559, 27.664089],
#      [85.421686, 27.664138],
#      [85.421809, 27.664185],
#      [85.422081, 27.664293],
#      [85.422163, 27.664355],
#      [85.422294, 27.664498],
#      [85.422666, 27.665026],
#      [85.422861, 27.665356],
#      [85.422999, 27.665647],
#      [85.423074, 27.665782],
#      [85.423121, 27.665873],
#      [85.423661, 27.665836],
#      [85.424737, 27.66582],
#      [85.425386, 27.665788],
#      [85.425623, 27.665764],
#      [85.425915, 27.665734],
#      [85.427171, 27.665548],
#      [85.427236, 27.665499],
#      [85.427268, 27.665493],
#      [85.42783, 27.665402],
#      [85.427976, 27.665383],
#      [85.428329, 27.665338],
#      [85.428834, 27.665278],
#      [85.429288, 27.665232],
#      [85.42938, 27.665244],
#      [85.429578, 27.665301],
#      [85.430137, 27.66554],
#      [85.431188, 27.665983],
#      [85.431454, 27.666096],
#      [85.431789, 27.666239],
#      [85.432347, 27.666448],
#      [85.432604, 27.666486],
#      [85.432897, 27.666493],
#      [85.433016, 27.666494],
#      [85.433563, 27.666497],
#      [85.433848, 27.666495],
#      [85.434889, 27.666492],
#      [85.435755, 27.666499],
#      [85.436478, 27.666498],
#      [85.436473, 27.66672],
#      [85.436457, 27.667002],
#      [85.436455, 27.667067],
#      [85.436476, 27.667307],
#      [85.436526, 27.667451],
#      [85.436618, 27.667582],
#      [85.436815, 27.667788],
#      [85.437056, 27.668068],
#      [85.43711, 27.668153],
#      [85.437179, 27.668304],
#      [85.437238, 27.668475],
#      [85.437283, 27.668629],
#      [85.437321, 27.668748],
#      [85.437375, 27.668945],
#      [85.437462, 27.669241],
#      [85.437532, 27.669552],
#      [85.437561, 27.669682],
#      [85.437598, 27.669828],
#      [85.437792, 27.67052],
#      [85.43803, 27.671406],
#      [85.438086, 27.671637],
#      [85.438171, 27.671942],
#      [85.438285, 27.672399],
#      [85.438313, 27.672608],
#      [85.438328, 27.673142],
#      [85.438336, 27.673434],
#      [85.438727, 27.673471],
#      [85.439012, 27.673505],
#      [85.439452, 27.67357],
#      [85.440376, 27.673706],
#      [85.440753, 27.673761],
#      [85.441032, 27.673798],
#      [85.441291, 27.673823],
#      [85.441448, 27.673844],
#      [85.442087, 27.673928],
#      [85.44256, 27.674001],
#      [85.442749, 27.674039],
#      [85.443171, 27.674112],
#      [85.443275, 27.674134],
#      [85.443505, 27.6742],
#      [85.443608, 27.674274],
#      [85.443709, 27.674431],
#      [85.443807, 27.674552],
#      [85.443876, 27.674603],
#      [85.443998, 27.674673],
#      [85.444294, 27.674775],
#      [85.444574, 27.674849],
#      [85.444792, 27.67489],
#      [85.445014, 27.674908],
#      [85.445328, 27.674882],
#      [85.445659, 27.674756],
#      [85.446164, 27.674523],
#      [85.446475, 27.674355],
#      [85.447546, 27.673614],
#      [85.447631, 27.673569],
#      [85.447764, 27.673513],
#      [85.448046, 27.673461],
#      [85.44857, 27.673379],
#      [85.448992, 27.673342],
#      [85.450937, 27.67315],
#      [85.450966, 27.673152],
#      [85.451214, 27.673163],
#      [85.45164, 27.673323],
#      [85.451951, 27.673475],
#      [85.452076, 27.673488],
#      [85.452437, 27.673403],
#      [85.452576, 27.673368],
#      [85.453439, 27.673135],
#      [85.453889, 27.673013],
#      [85.454136, 27.672917],
#      [85.45471, 27.672632],
#      [85.454824, 27.672588],
#      [85.455002, 27.672585],
#      [85.45519, 27.672602],
#      [85.456611, 27.672314],
#      [85.456906, 27.672231],
#      [85.457014, 27.672195],
#      [85.457915, 27.672017],
#      [85.458151, 27.67195],
#      [85.458371, 27.671887],
#      [85.458462, 27.671861],
#      [85.458934, 27.671706],
#      [85.459109, 27.671647],
#      [85.459253, 27.67159],
#      [85.459618, 27.671466],
#      [85.459872, 27.671395],
#      [85.460045, 27.67135],
#      [85.460356, 27.671303],
#      [85.460646, 27.671222],
#      [85.46096, 27.671108],
#      [85.461284, 27.670908],
#      [85.461417, 27.670862],
#      [85.461886, 27.670841],
#      [85.462117, 27.670804],
#      [85.462416, 27.670697],
#      [85.46256, 27.670611],
#      [85.462662, 27.670486],
#      [85.462837, 27.669993],
#      [85.462936, 27.669839],
#      [85.463043, 27.669718],
#      [85.463395, 27.66941],
#      [85.463518, 27.669331],
#      [85.46394, 27.66914],
#      [85.464115, 27.669087],
#      [85.464248, 27.669086],
#      [85.464969, 27.669079],
#      [85.465507, 27.669111],
#      [85.465787, 27.669075],
#      [85.466303, 27.668888],
#      [85.46636, 27.668884],
#      [85.46651, 27.668886],
#      [85.466611, 27.668907],
#      [85.466705, 27.668949],
#      [85.466794, 27.668944],
#      [85.46704, 27.669183],
#      [85.467208, 27.669341],
#      [85.467498, 27.669537],
#      [85.46806, 27.669685],
#      [85.468459, 27.669723],
#      [85.468558, 27.669733],
#      [85.468756, 27.669732],
#      [85.468943, 27.66968],
#      [85.470264, 27.66874],
#      [85.470417, 27.668661],
#      [85.470833, 27.668592],
#      [85.471109, 27.66857],
#      [85.471817, 27.668454],
#      [85.47238, 27.668318],
#      [85.472721, 27.668235],
#      [85.472943, 27.668136],
#      [85.473118, 27.667999],
#      [85.473504, 27.667696],
#      [85.473883, 27.667429],
#      [85.474064, 27.66734],
#      [85.474212, 27.667288],
#      [85.474839, 27.667308],
#      [85.475629, 27.667182],
#      [85.475779, 27.667132],
#      [85.476429, 27.666891],
#      [85.477573, 27.666549],
#      [85.478094, 27.666448],
#      [85.478258, 27.666476],
#      [85.478689, 27.666812],
#      [85.479165, 27.667357],
#      [85.479329, 27.667457],
#      [85.479898, 27.667666],
#      [85.480062, 27.667796],
#      [85.480137, 27.667813],
#      [85.480183, 27.667809],
#      [85.480255, 27.667783],
#      [85.480565, 27.667597],
#      [85.480639, 27.667497],
#      [85.480869, 27.66698],
#      [85.480924, 27.666795],
#      [85.480906, 27.666484],
#      [85.480906, 27.666112],
#      [85.480928, 27.665988],
#      [85.480993, 27.665835],
#      [85.481057, 27.665762],
#      [85.481185, 27.665669],
#      [85.48131, 27.665606],
#      [85.481414, 27.665597],
#      [85.481512, 27.665612],
#      [85.481628, 27.665652],
#      [85.481753, 27.66574],
#      [85.481891, 27.665805],
#      [85.481957, 27.665819],
#      [85.482495, 27.665852],
#      [85.48272, 27.665834],
#      [85.482792, 27.665801],
#      [85.482909, 27.665703],
#      [85.483197, 27.665411],
#      [85.483313, 27.665345],
#      [85.483466, 27.665299],
#      [85.483595, 27.665301],
#      [85.483689, 27.665309],
#      [85.484528, 27.665448],
#      [85.484713, 27.66551],
#      [85.485013, 27.665729],
#      [85.48517, 27.665809],
#      [85.485315, 27.665846],
#      [85.485512, 27.665861],
#      [85.48575, 27.66584],
#      [85.485942, 27.6658],
#      [85.486039, 27.665804],
#      [85.48635, 27.665858],
#      [85.486526, 27.665858],
#      [85.486814, 27.665809],
#      [85.48692, 27.665769],
#      [85.486998, 27.665727],
#      [85.487089, 27.665625],
#      [85.48728, 27.665361],
#      [85.487364, 27.665273],
#      [85.487469, 27.665196],
#      [85.487999, 27.664816],
#      [85.48821, 27.664764],
#      [85.488868, 27.66482],
#      [85.488956, 27.664812],
#      [85.489034, 27.664758],
#      [85.489037, 27.664716],
#      [85.48901, 27.664689],
#      [85.488963, 27.664671],
#      [85.488248, 27.664512],
#      [85.488192, 27.664477],
#      [85.48808, 27.664355],
#      [85.487971, 27.664277],
#      [85.487685, 27.664143],
#      [85.487586, 27.664077],
#      [85.487508, 27.663993],
#      [85.487456, 27.663915],
#      [85.487405, 27.663834],
#      [85.48737, 27.663749],
#      [85.487368, 27.663702],
#      [85.487386, 27.663655],
#      [85.487413, 27.663632],
#      [85.487453, 27.663626],
#      [85.487496, 27.663645],
#      [85.487532, 27.663677],
#      [85.487666, 27.663881],
#      [85.487714, 27.663928],
#      [85.487807, 27.663973],
#      [85.487902, 27.663996],
#      [85.487973, 27.663992],
#      [85.488048, 27.663966],
#      [85.488288, 27.663822],
#      [85.488384, 27.663786],
#      [85.488484, 27.663783],
#      [85.489006, 27.663866],
#      [85.489089, 27.663859],
#      [85.48916, 27.663831],
#      [85.489213, 27.663771],
#      [85.489404, 27.663221],
#      [85.489447, 27.663169],
#      [85.489501, 27.663144],
#      [85.489557, 27.663147],
#      [85.489717, 27.663235],
#      [85.489756, 27.663293],
#      [85.489777, 27.663366],
#      [85.489767, 27.663426],
#      [85.489731, 27.6635],
#      [85.489472, 27.663886],
#      [85.489466, 27.663951],
#      [85.489523, 27.6641],
#      [85.489574, 27.664151],
#      [85.489635, 27.664172],
#      [85.489754, 27.664168],
#      [85.490322, 27.664018],
#      [85.490653, 27.663861],
#      [85.491676, 27.66323],
#      [85.492129, 27.662971],
#      [85.492781, 27.662629],
#      [85.492977, 27.662491],
#      [85.493197, 27.662309],
#      [85.493532, 27.661955],
#      [85.493621, 27.661828],
#      [85.493994, 27.661508],
#      [85.494616, 27.660767],
#      [85.49546, 27.659607],
#      [85.495586, 27.659476],
#      [85.495827, 27.659324],
#      [85.495973, 27.659287],
#      [85.496159, 27.65921],
#      [85.496241, 27.659073],
#      [85.496412, 27.658694],
#      [85.49655, 27.658485],
#      [85.496637, 27.658369],
#      [85.496839, 27.658263],
#      [85.497091, 27.65804],
#      [85.497343, 27.657776],
#      [85.497595, 27.657643],
#      [85.497782, 27.657543],
#      [85.498011, 27.657436],
#      [85.49818, 27.657393],
#      [85.49879, 27.657396],
#      [85.498872, 27.657389],
#      [85.499039, 27.657412],
#      [85.499167, 27.65744],
#      [85.499319, 27.657398],
#      [85.499639, 27.65728],
#      [85.499846, 27.657248],
#      [85.499959, 27.657253],
#      [85.500156, 27.657187],
#      [85.500449, 27.657118],
#      [85.50212, 27.656936],
#      [85.502132, 27.65693],
#      [85.502193, 27.656908],
#      [85.502284, 27.656864],
#      [85.502442, 27.65679],
#      [85.503183, 27.656353],
#      [85.50428, 27.655654],
#      [85.504478, 27.655545],
#      [85.505109, 27.65532],
#      [85.505222, 27.655256],
#      [85.505492, 27.655116],
#      [85.50554, 27.655135],
#      [85.505943, 27.655141],
#      [85.506084, 27.65517],
#      [85.505981, 27.655265],
#      [85.505703, 27.655446],
#      [85.505437, 27.655759],
#      [85.505308, 27.655933],
#      [85.505277, 27.656085],
#      [85.505245, 27.656451],
#      [85.505132, 27.656654],
#      [85.505041, 27.656751],
#      [85.504957, 27.656772],
#      [85.504806, 27.65677],
#      [85.504689, 27.656819],
#      [85.504588, 27.656899],
#      [85.504332, 27.657025],
#      [85.50424, 27.657139],
#      [85.504171, 27.657415],
#      [85.504184, 27.657502],
#      [85.504285, 27.657777],
#      [85.504379, 27.657884],
#      [85.504427, 27.65797],
#      [85.50443, 27.658209],
#      [85.504456, 27.658347],
#      [85.504548, 27.658449],
#      [85.504562, 27.658513],
#      [85.504259, 27.658955],
#      [85.504161, 27.65914],
#      [85.503928, 27.659228],
#      [85.503764, 27.659322],
#      [85.503662, 27.659421],
#      [85.503284, 27.659987],
#      [85.503255, 27.660089],
#      [85.503165, 27.660238],
#      [85.503138, 27.660292],
#      [85.50307, 27.660614],
#      [85.503081, 27.660747],
#      [85.503249, 27.661056],
#      [85.503323, 27.66143],
#      [85.503388, 27.661501],
#      [85.503471, 27.661475],
#      [85.50346, 27.661172],
#      [85.503505, 27.661056],
#      [85.503618, 27.660923],
#      [85.503712, 27.660879],
#      [85.503784, 27.6609],
#      [85.503792, 27.660972],
#      [85.503763, 27.661181],
#      [85.503779, 27.661263],
#      [85.503876, 27.661393],
#      [85.504122, 27.661557],
#      [85.504415, 27.661612],
#      [85.504885, 27.661817],
#      [85.50509, 27.661756],
#      [85.505235, 27.661638],
#      [85.505397, 27.661618],
#      [85.505504, 27.661656],
#      [85.505637, 27.661745],
#      [85.50567, 27.661835],
#      [85.505648, 27.661908],
#      [85.505571, 27.662008],
#      [85.505577, 27.662348],
#      [85.505779, 27.662722],
#      [85.505876, 27.662817],
#      [85.505985, 27.662981],
#      [85.506083, 27.663065],
#      [85.506364, 27.662857],
#      [85.506631, 27.662801],
#      [85.506688, 27.662902],
#      [85.506753, 27.663123],
#      [85.506894, 27.663228],
#      [85.506913, 27.663368],
#      [85.506971, 27.663426],
#      [85.507025, 27.663521],
#      [85.507003, 27.663654],
#      [85.507021, 27.663711],
#      [85.50711, 27.663857],
#      [85.507093, 27.664053],
#      [85.507053, 27.66412],
#      [85.507135, 27.664213],
#      [85.507243, 27.664247],
#      [85.50735, 27.664316],
#      [85.507472, 27.664434],
#      [85.507505, 27.664525],
#      [85.507541, 27.66464],
#      [85.507547, 27.664791],
#      [85.507576, 27.664919],
#      [85.507662, 27.66511],
#      [85.507804, 27.665657],
#      [85.507885, 27.665798],
#      [85.508353, 27.666207],
#      [85.508667, 27.666377],
#      [85.508877, 27.666562],
#      [85.509094, 27.666703],
#      [85.509466, 27.666879],
#      [85.509585, 27.667099],
#      [85.509715, 27.667401],
#      [85.509756, 27.667438],
#      [85.509859, 27.667494],
#      [85.510159, 27.66756],
#      [85.51023, 27.667621],
#      [85.510244, 27.667654],
#      [85.51023, 27.667689],
#      [85.510174, 27.667736],
#      [85.509966, 27.667744],
#      [85.509878, 27.667791],
#      [85.509698, 27.667925],
#      [85.509611, 27.668051],
#      [85.509604, 27.668132],
#      [85.509638, 27.668204],
#      [85.50975, 27.668261],
#      [85.509906, 27.668292],
#      [85.510307, 27.668412],
#      [85.510511, 27.668499],
#      [85.510674, 27.668673],
#      [85.510746, 27.668845],
#      [85.510963, 27.668735],
#      [85.511089, 27.668663],
#      [85.511212, 27.668693],
#      [85.511256, 27.668742],
#      [85.511159, 27.668915],
#      [85.511165, 27.668987],
#      [85.511332, 27.669294],
#      [85.511385, 27.669544],
#      [85.511451, 27.669706],
#      [85.511582, 27.669952],
#      [85.51159, 27.67015],
#      [85.511575, 27.670469],
#      [85.511603, 27.670584],
#      [85.511732, 27.670717],
#      [85.512128, 27.671073],
#      [85.512257, 27.67116],
#      [85.512516, 27.671235],
#      [85.512635, 27.671326],
#      [85.513045, 27.67139],
#      [85.513207, 27.671463],
#      [85.513317, 27.671484],
#      [85.513639, 27.671639],
#      [85.513843, 27.671689],
#      [85.514113, 27.671877],
#      [85.514373, 27.672108],
#      [85.514456, 27.672219],
#      [85.514464, 27.672315],
#      [85.514432, 27.67268],
#      [85.514477, 27.672796],
#      [85.514573, 27.672904],
#      [85.514711, 27.672994],
#      [85.515086, 27.67312],
#      [85.515153, 27.6733],
#      [85.515175, 27.673433],
#      [85.515452, 27.673755],
#      [85.515489, 27.674004],
#      [85.515174, 27.674926],
#      [85.515254, 27.675488],
#      [85.515426, 27.675808],
#      [85.51556, 27.676118],
#      [85.515737, 27.676337],
#      [85.515817, 27.676479]],
#     'type': 'LineString'}}],
#  'bbox': [85.404827, 27.648867, 85.515817, 27.676479],
#  'metadata': {'attribution': 'openrouteservice.org | OpenStreetMap contributors',
#   'service': 'routing',
#   'timestamp': 1683953611470,
#   'query': {'coordinates': [[85.403445, 27.64979], [85.516931, 27.676529]],
#    'profile': 'driving-car',
#    'format': 'json'},
#   'engine': {'version': '6.8.1',
#    'build_date': '2023-02-27T01:00:29Z',
#    'graph_date': '2023-05-03T13:04:56Z'}}}

# %%
way_coordinates=result.json()['features'][0]['geometry']['coordinates']

# %%
folium.PolyLine(locations=[list(reversed(coord)) for coord in way_coordinates], color="blue").add_to(map)

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0bfd3a315762f0d811383f31170bc7cc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0bfd3a315762f0d811383f31170bc7cc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0bfd3a315762f0d811383f31170bc7cc = L.map(
#                 &quot;map_0bfd3a315762f0d811383f31170bc7cc&quot;,
#                 {
#                     center: [27.705194, 85.391806],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_130d6421496f88f330ce15d710675ce9 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0bfd3a315762f0d811383f31170bc7cc);
#
#
#             var marker_4bf30d2bfa6ce8be501ae0068c1f0eac = L.marker(
#                 [27.705194, 85.391806],
#                 {}
#             ).addTo(map_0bfd3a315762f0d811383f31170bc7cc);
#
#
#             var marker_894b98f6bc2b1d1a1b91edf94e24b656 = L.marker(
#                 [27.64979, 85.403445],
#                 {}
#             ).addTo(map_0bfd3a315762f0d811383f31170bc7cc);
#
#
#             var marker_4fba494b9a048095280d9fdd71f2f159 = L.marker(
#                 [27.676529, 85.516931],
#                 {}
#             ).addTo(map_0bfd3a315762f0d811383f31170bc7cc);
#
#
#             var poly_line_dde5121686fcbe708efb191333357e15 = L.polyline(
#                 [[27.650501, 85.404827], [27.650411, 85.404919], [27.650384, 85.404945], [27.650209, 85.405104], [27.650319, 85.405212], [27.650236, 85.405395], [27.650141, 85.405789], [27.649946, 85.406454], [27.649787, 85.406763], [27.649523, 85.407428], [27.649466, 85.407704], [27.649397, 85.407878], [27.649245, 85.408377], [27.648934, 85.409083], [27.648875, 85.409241], [27.648867, 85.409319], [27.649341, 85.409579], [27.64991, 85.40976], [27.650388, 85.410178], [27.650365, 85.411042], [27.650458, 85.411168], [27.65058, 85.411255], [27.650721, 85.411295], [27.650865, 85.411284], [27.650999, 85.411223], [27.651271, 85.411034], [27.651536, 85.410971], [27.651717, 85.410798], [27.652133, 85.410791], [27.652625, 85.410858], [27.652559, 85.410895], [27.652237, 85.410908], [27.652104, 85.410957], [27.651854, 85.410951], [27.651566, 85.411637], [27.651551, 85.411903], [27.651627, 85.412371], [27.651634, 85.412418], [27.651748, 85.412615], [27.652037, 85.412915], [27.65258, 85.413209], [27.652789, 85.413291], [27.652868, 85.4133], [27.652942, 85.413288], [27.653345, 85.413121], [27.653619, 85.413053], [27.653999, 85.412872], [27.654441, 85.412786], [27.654795, 85.412673], [27.654924, 85.412646], [27.655077, 85.412637], [27.655606, 85.412685], [27.655953, 85.412643], [27.656087, 85.41266], [27.656432, 85.412755], [27.657114, 85.412712], [27.657673, 85.412491], [27.658018, 85.412448], [27.658082, 85.412418], [27.658534, 85.412069], [27.658644, 85.412019], [27.658739, 85.412015], [27.659034, 85.412048], [27.659299, 85.412103], [27.659407, 85.412138], [27.659568, 85.41221], [27.659764, 85.412434], [27.659847, 85.412477], [27.659918, 85.412489], [27.660392, 85.412357], [27.660543, 85.41237], [27.661236, 85.412503], [27.661309, 85.412535], [27.661367, 85.412591], [27.661601, 85.412872], [27.661791, 85.413147], [27.661892, 85.413241], [27.662014, 85.4133], [27.662335, 85.413538], [27.662711, 85.414098], [27.662809, 85.414329], [27.662796, 85.414763], [27.662725, 85.4151], [27.662762, 85.415624], [27.662754, 85.415988], [27.662732, 85.41611], [27.662649, 85.416332], [27.662363, 85.416875], [27.662275, 85.417167], [27.662206, 85.417754], [27.662251, 85.419298], [27.66227, 85.419542], [27.662314, 85.419835], [27.662336, 85.419899], [27.66253, 85.42008], [27.662584, 85.420143], [27.66269, 85.420234], [27.662868, 85.420395], [27.663527, 85.420822], [27.663596, 85.420926], [27.663606, 85.421027], [27.663624, 85.421082], [27.663793, 85.421255], [27.663952, 85.42135], [27.664089, 85.421559], [27.664138, 85.421686], [27.664185, 85.421809], [27.664293, 85.422081], [27.664355, 85.422163], [27.664498, 85.422294], [27.665026, 85.422666], [27.665356, 85.422861], [27.665647, 85.422999], [27.665782, 85.423074], [27.665873, 85.423121], [27.665836, 85.423661], [27.66582, 85.424737], [27.665788, 85.425386], [27.665764, 85.425623], [27.665734, 85.425915], [27.665548, 85.427171], [27.665499, 85.427236], [27.665493, 85.427268], [27.665402, 85.42783], [27.665383, 85.427976], [27.665338, 85.428329], [27.665278, 85.428834], [27.665232, 85.429288], [27.665244, 85.42938], [27.665301, 85.429578], [27.66554, 85.430137], [27.665983, 85.431188], [27.666096, 85.431454], [27.666239, 85.431789], [27.666448, 85.432347], [27.666486, 85.432604], [27.666493, 85.432897], [27.666494, 85.433016], [27.666497, 85.433563], [27.666495, 85.433848], [27.666492, 85.434889], [27.666499, 85.435755], [27.666498

# %% [markdown]
# ## classify

# %% [markdown]
# ## garbage-classification

# %%
import requests

API_URL = "https://api-inference.huggingface.co/models/yangy50/garbage-classification"
headers = {"Authorization": "Bearer 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"}

def query(filename):
    with open(filename, "rb") as f:
        data = f.read()
    response = requests.post(API_URL, headers=headers, data=data)
    return response.json()

# %%
query("card.png")
# Out:
# [{'score': 0.24889208376407623, 'label': 'metal'},
#  {'score': 0.18996791541576385, 'label': 'cardboard'},
#  {'score': 0.18191617727279663, 'label': 'trash'},
#  {'score': 0.1668497622013092, 'label': 'paper'},
#  {'score': 0.1194106861948967, 'label': 'plastic'}]

# %%
a[0]
# Out:
# {'score': 0.24889208376407623, 'label': 'metal'}

# %% [markdown]
# ### detection
